# %% [markdown]
# <a href="https://colab.research.google.com/github/AchrafAsh/cyclegan-deepfake/blob/master/CycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Take a look at the [repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix) for more information

# %% [markdown]
# # Install

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2508, done.
# remote: Total 2508 (delta 0), reused 0 (delta 0), pack-reused 2508
# Receiving objects: 100% (2508/2508), 8.19 MiB | 21.35 MiB/s, done.
# Resolving deltas: 100% (1573/1573), done.

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 1)) (1.13.1+cu116)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 2)) (0.14.1+cu116)
# Collecting dominate>=2.4.0
#   Downloading dominate-2.7.0-py2.py3-none-any.whl (29 kB)
# Collecting visdom>=0.1.8.8
#   Downloading visdom-0.2.4.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 44.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting wandb
#   Downloading wandb-0.13.11-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 73.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.5.0->-r requirements.txt (line 2)) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.5.0->-r requirements.txt (line 2)) (8.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.5.0->-r requirements.txt (line 2)) (2.25.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.10.1)
# Requirement already satisfied: tornado in /usr/local/lib/python3.9/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (6.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.15.0)
# Collecting jsonpatch
#   Downloading jsonpatch-1.32-py2.py3-none-any.whl (12 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (3.0)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.16.0-py2.py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 5)) (3.19.6)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 5)) (5.4.8)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 5)) (6.0)
# Collecting appdirs>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 5)) (57.4.0)
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 23.0 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 5)) (8.1.3)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.5.0->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.5.0->-r requirements.txt (line 2)) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.5.0->-r requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.5.0->-r requirements.txt (line 2)) (4.0.0)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: visdom, pathtools
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408217 sha256=896fd4521d8022439c36b60a067fd2072d855ebb986700983e857858524a5a6c
#   Stored in directory: /root/.cache/pip/wheels/58/9e/14/30f7cc4dafdd4d602fb00ca33c6edd1424fc0f5df10a02e060
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=1f578bf405e4b7aaa46561d413646b596c23515b4c46458e116c0328c63dd7e0
#   Stored in directory: /root/.cache/pip/wheels/b7/0a/67/ada2a22079218c75a88361c0782855cc72aebc4d18d0289d05
# Successfully built visdom pathtools
# Installing collected packages: pathtools, appdirs, websocket-client, smmap, setproctitle, sentry-sdk, jsonpointer, dominate, docker-pycreds, jsonpatch, gitdb, visdom, GitPython, wandb
# Successfully installed GitPython-3.1.31 appdirs-1.4.4 docker-pycreds-0.4.0 dominate-2.7.0 gitdb-4.0.10 jsonpatch-1.32 jsonpointer-2.3 pathtools-0.1.2 sentry-sdk-1.16.0 setproctitle-1.3.2 smmap-5.0.0 visdom-0.2.4 wandb-0.13.11 websocket-client-1.5.1

# %% [markdown]
# # Datasets
#
# Download one of the official datasets with:
#
# -   `bash ./datasets/download_cyclegan_dataset.sh [apple2orange, summer2winter_yosemite, horse2zebra, monet2photo, cezanne2photo, ukiyoe2photo, vangogh2photo, maps, cityscapes, facades, iphone2dslr_flower, ae_photos]`
#
# Or use your own dataset by creating the appropriate folders and adding in the images.
#
# -   Create a dataset folder under `/dataset` for your dataset.
# -   Create subfolders `testA`, `testB`, `trainA`, and `trainB` under your dataset's folder. Place any images you want to transform from a to b (cat2dog) in the `testA` folder, images you want to transform from b to a (dog2cat) in the `testB` folder, and do the same for the `trainA` and `trainB` folders.

# %%
# !bash ./datasets/download_cyclegan_dataset.sh horse2zebra

# %%
# !unzip ./datasets/caillet2cruise.zip

# %%
# !rm -r ./checkpoints

# %% [markdown]
# # Pretrained models
#
# Download one of the official pretrained models with:
#
# -   `bash ./scripts/download_cyclegan_model.sh [apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower]`
#
# Or add your own pretrained model to `./checkpoints/{NAME}_pretrained/latest_net_G.pt`

# %%
# !bash ./scripts/download_cyclegan_model.sh horse2zebra

# %% [markdown]
# # Training
#
# -   `python train.py --dataroot ./datasets/horse2zebra --name horse2zebra --model cycle_gan`
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size. I've found that a batch size of 16 fits onto 4 V100s and can finish training an epoch in ~90s.
#
# Once your model has trained, copy over the last checkpoint to a format that the testing model can automatically detect:
#
# Use `cp ./checkpoints/horse2zebra/latest_net_G_A.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class A to class B and `cp ./checkpoints/horse2zebra/latest_net_G_B.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class B to class A.

# %%
# !python train.py --dataroot ./datasets/caillet2cruise --name caillet2cruise --model cycle_gan --n_epochs 200 --display_id -1
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/caillet2cruise     	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: -1                            	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
#                 load_iter: 0                             	[default: 0]
#                 load_size: 286
#                        lr: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: cycle_gan
#                  n_epochs: 200                           	[default: 100]
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: caillet2cruise                	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: resnet_9blocks
#                       ngf: 64
#                no_dropout: True
#                   no_flip: False
#                   no_html: False
#                      norm: instance
#               num_threads: 4
#                 output_nc: 3
#                     phase: train
#                 pool_size: 50
#                preprocess: resize_and_crop
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                    suffix:
#          update_html_freq: 1000
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [UnalignedDataset] was created
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# The number of training images = 12
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [CycleGANModel] was created
# ---------- Networks initialized -------------
# [Network G_A] Total number of parameters : 11.378 M
# [Network G_B] Total number of parameters : 11.378 M
# [Network D_A] Total number of parameters : 2.765 M
# [Network D_B] Total number of parameters : 2.765 M
# -----------------------------------------------
# create web directory ./checkpoints/caillet2cruise/web...
# /usr/local/lib/python3.9/dist-packages/torch/optim/lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# learning rate 0.0002000 -> 0.0002000
# End of epoch 1 / 300 	 Time Taken: 9 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 2 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 3 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 4 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# saving the model at the end of epoch 5, iters 60
# End of epoch 5 / 300 	 Time Taken: 7 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 6 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 7 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 8 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# (epoch: 9, iters: 4, time: 0.554, data: 0.319) D_A: 0.267 G_A: 0.572 cycle_A: 0.746 idt_A: 0.428 D_B: 0.187 G_B: 0.336 cycle_B: 0.892 idt_B: 0.375
# End of epoch 9 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# saving the model at the end of epoch
/ 300 	 Time Taken: 7 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 168 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 169 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# saving the model at the end of epoch 170, iters 2040
# End of epoch 170 / 300 	 Time Taken: 7 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 171 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 172 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 173 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 174 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# (epoch: 175, iters: 12, time: 0.554, data: 0.002) D_A: 0.397 G_A: 0.719 cycle_A: 0.370 idt_A: 0.228 D_B: 0.252 G_B: 0.487 cycle_B: 0.536 idt_B: 0.124
# saving the model at the end of epoch 175, iters 2100
# End of epoch 175 / 300 	 Time Taken: 7 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 176 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 177 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 178 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 179 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# saving the model at the end of epoch 180, iters 2160
# End of epoch 180 / 300 	 Time Taken: 7 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 181 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 182 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 183 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# (epoch: 184, iters: 4, time: 0.560, data: 0.302) D_A: 0.119 G_A: 0.703 cycle_A: 0.586 idt_A: 0.272 D_B: 0.292 G_B: 0.509 cycle_B: 0.547 idt_B: 0.203
# End of epoch 184 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# saving the model at the end of epoch 185, iters 2220
# End of epoch 185 / 300 	 Time Taken: 7 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 186 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 187 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 188 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 189 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# saving the model at the end of epoch 190, iters 2280
# End of epoch 190 / 300 	 Time Taken: 7 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 191 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# (epoch: 192, iters: 8, time: 0.550, data: 0.004) D_A: 0.351 G_A: 0.061 cycle_A: 0.511 idt_A: 0.121 D_B: 0.304 G_B: 0.247 cycle_B: 0.307 idt_B: 0.215
# End of epoch 192 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 193 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 194 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# saving the model at the end of epoch 195, iters 2340
# End of epoch 195 / 300 	 Time Taken: 7 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 196 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 197 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 198 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0002000
# End of epoch 199 / 300 	 Time Taken: 6 sec
# learning rate 0.0002000 -> 0.0001980
# (epoch: 200, iters: 12, time: 1.925, data: 0.002) D_A: 0.220 G_A: 0.356 cycle_A: 0.470 idt_A: 0.151 D_B: 0.147 G_B: 0.436 cycle_B: 0.440 idt_B: 0.159
# saving the model at the end of epoch 200, iters 2400
# End of epoch 200 / 300 	 Time Taken: 8 sec
# learning rate 0.0001980 -> 0.0001960
# End of epoch 201 / 300 	 Time Taken: 6 sec
# learning rate 0.0001960 -> 0.0001941
# End of epoch 202 / 300 	 Time Taken: 6 sec
# learning rate 0.0001941 -> 0.0001921
# End of epoch 203 / 300 	 Time Taken: 6 sec
# learning rate 0.0001921 -> 0.0001901
# End of epoch 204 / 300 	 Time Taken: 6 sec
# learning rate 0.0001901 -> 0.0001881
# saving the model at the end of epoch 205, iters 2460
# End of epoch 205 / 300 	 Time Taken: 7 sec
# learning rate 0.0001881 -> 0.0001861
# End of epoch 206 / 300 	 Time Taken: 6 sec
# learning rate 0.0001861 -> 0.0001842
# End of epoch 207 / 300 	 Time Taken: 6 sec
# learning rate 0.0001842 -> 0.0001822
# End of epoch 208 / 300 	 Time Taken: 6 sec
# learning rate 0.0001822 -> 0.0001802
# (epoch: 209, iters: 4, time: 0.561, data: 0.211) D_A: 0.198 G_A: 0.216 cycle_A: 0.416 idt_A: 0.118 D_B: 0.232 G_B: 0.329 cycle_B: 0.340 idt_B: 0.162
# End of epoch 209 / 300 	 Time Taken: 6 sec
# learning rate 0.0001802 -> 0.0001782
# saving the model at the end of epoch 210, iters 2520
# End of epoch 210 / 300 	 Time Taken: 7 sec
# learning rate 0.0001782 -> 0.0001762
# End of epoch 211 / 300 	 Time Taken: 6 sec
# learning rate 0.0001762 -> 0.0001743
# End of epoch 212 / 300 	 Time Taken: 6 sec
# learning rate 0.0001743 -> 0.0001723
# End of epoch 213 / 300 	 Time Taken: 6 sec
# learning rate 0.0001723 -> 0.0001703
# End of epoch 214 / 300 	 Time Taken: 6 sec
# learning rate 0.0001703 -> 0.0001683
# saving the model at the end of epoch 215, iters 2580
# End of epoch 215 / 300 	 Time Taken: 7 sec
# learning rate 0.0001683 -> 0.0001663
# End of epoch 216 / 300 	 Time Taken: 6 sec
# learning rate 0.0001663 -> 0.0001644
# (epoch: 217, iters: 8, time: 0.553, data: 0.002) D_A: 0.219 G_A: 0.273 cycle_A: 0.392 idt_A: 0.106 D_B: 0.159 G_B: 0.200 cycle_B: 0.298 idt_B: 0.148
# End of epoch 217 / 300 	 Time Taken: 6 sec
# learning rate 0.0001644 -> 0.0001624
# End of epoch 218 / 300 	 Time Taken: 6 sec
# learning rate 0.0001624 -> 0.0001604
# End of epoch 219 / 300 	 Time Taken: 6 sec
# learning rate 0.0001604 -> 0.0001584
# saving the model at the end of epoch 220, iters 2640
# End of epoch 220 / 300 	 Time Taken: 7 sec
# learning rate 0.0001584 -> 0.0001564
# End of epoch 221 / 300 	 Time Taken: 6 sec
# learning rate 0.0001564 -> 0.0001545
# End of epoch 222 / 300 	 Time Taken: 6 sec
# learning rate 0.0001545 -> 0.0001525
# End of epoch 223 / 300 	 Time Taken: 6 sec
# learning rate 0.0001525 -> 0.0001505
# End of epoch 224 / 300 	 Time Taken: 6 sec
# learning rate 0.0001505 -> 0.0001485
# (epoch: 225, iters: 12, time: 0.557, data: 0.000) D_A: 0.287 G_A: 0.340 cycle_A: 0.350 idt_A: 0.114 D_B: 0.228 G_B: 0.180 cycle_B: 0.310 idt_B: 0.123
# saving the model at the end of epoch 225, iters 2700
# End of epoch 225 / 300 	 Time Taken: 7 sec
# learning rate 0.0001485 -> 0.0001465
# End of epoch 226 / 300 	 Time Taken: 6 sec
# learning rate 0.0001465 -> 0.0001446
# End of epoch 227 / 300 	 Time Taken: 6 sec
# learning rate 0.0001446 -> 0.0001426
# End of epoch 228 / 300 	 Time Taken: 6 sec
# learning rate 0.0001426 -> 0.0001406
# End of epoch 229 / 300 	 Time Taken: 6 sec
# learning rate 0.0001406 -> 0.0001386
# saving the model at the end of epoch 230, iters 2760
# End of epoch 230 / 300 	 Time Taken: 7 sec
# learning rate 0.0001386 -> 0.0001366
# End of epoch 231 / 300 	 Time Taken: 6 sec
# learning rate 0.0001366 -> 0.0001347
# End of epoch 232 / 300 	 Time Taken: 6 sec
# learning rate 0.0001347 -> 0.0001327
# End of epoch 233 / 300 	 Time Taken: 6 sec
# learning rate 0.0001327 -> 0.0001307
# (epoch: 234, iters: 4, time: 2.494, data: 0.208) D_A: 0.158 G_A: 0.333 cycle_A: 0.259 idt_A: 0.101 D_B: 0.199 G_B: 0.311 cycle_B: 0.278 idt_B: 0.101
# End of epoch 234 / 300 	 Time Taken: 8 sec
# learning rate 0.0001307 -> 0.0001287
# saving the model at the end of epoch 235, iters 2820
# End of epoch 235 / 300 	 Time Taken: 7 sec
# learning rate 0.0001287 -> 0.0001267
# End of epoch 236 / 300 	 Time Taken: 6 sec
# learning rate 0.0001267 -> 0.0001248
# End of epoch 237 / 300 	 Time Taken: 6 sec
# learning rate 0.0001248 -> 0.0001228
# End of epoch 238 / 300 	 Time Taken: 6 sec
# learning rate 0.0001228 -> 0.0001208
# End of epoch 239 / 300 	 Time Taken: 6 sec
# learning rate 0.0001208 -> 0.0001188
# saving the model at the end of epoch 240, iters 2880
# End of epoch 240 / 300 	 Time Taken: 7 sec
# learning rate 0.0001188 -> 0.0001168
# End of epoch 241 / 300 	 Time Taken: 6 sec
# learning rate 0.0001168 -> 0.0001149
# (epoch: 242, iters: 8, time: 0.558, data: 0.000) D_A: 0.180 G_A: 0.205 cycle_A: 0.346 idt_A: 0.127 D_B: 0.193 G_B: 0.433 cycle_B: 0.339 idt_B: 0.126
# End of epoch 242 / 300 	 Time Taken: 6 sec
# learning rate 0.0001149 -> 0.0001129
# End of epoch 243 / 300 	 Time Taken: 6 sec
# learning rate 0.0001129 -> 0.0001109
# End of epoch 244 / 300 	 Time Taken: 6 sec
# learning rate 0.0001109 -> 0.0001089
# saving the model at the end of epoch 245, iters 2940
# End of epoch 245 / 300 	 Time Taken: 7 sec
# learning rate 0.0001089 -> 0.0001069
# End of epoch 246 / 300 	 Time Taken: 6 sec
# learning rate 0.0001069 -> 0.0001050
# End of epoch 247 / 300 	 Time Taken: 6 sec
# learning rate 0.0001050 -> 0.0001030
# End of epoch 248 / 300 	 Time Taken: 6 sec
# learning rate 0.0001030 -> 0.0001010
# End of epoch 249 / 300 	 Time Taken: 6 sec
# learning rate 0.0001010 -> 0.0000990
# (epoch: 250, iters: 12, time: 0.554, data: 0.000) D_A: 0.223 G_A: 0.209 cycle_A: 0.333 idt_A: 0.092 D_B: 0.226 G_B: 0.192 cycle_B: 0.267 idt_B: 0.112
# saving the model at the end of epoch 250, iters 3000
# End of epoch 250 / 300 	 Time Taken: 7 sec
# learning rate 0.0000990 -> 0.0000970
# End of epoch 251 / 300 	 Time Taken: 6 sec
# learning rate 0.0000970 -> 0.0000950
# End of epoch 252 / 300 	 Time Taken: 6 sec
# learning rate 0.0000950 -> 0.0000931
# End of epoch 253 / 300 	 Time Taken: 6 sec
# learning rate 0.0000931 -> 0.0000911
# End of epoch 254 / 300 	 Time Taken: 6 sec
# learning rate 0.0000911 -> 0.0000891
# saving the model at the end of epoch 255, iters 3060
# End of epoch 255 / 300 	 Time Taken: 7 sec
# learning rate 0.0000891 -> 0.0000871
# End of epoch 256 / 300 	 Time Taken: 6 sec
# learning rate 0.0000871 -> 0.0000851
# End of epoch 257 / 300 	 Time Taken: 6 sec
# learning rate 0.0000851 -> 0.0000832
# End of epoch 258 / 300 	 Time Taken: 6 sec
# learning rate 0.0000832 -> 0.0000812
# (epoch: 259, iters: 4, time: 0.555, data: 0.201) D_A: 0.197 G_A: 0.317 cycle_A: 0.393 idt_A: 0.095 D_B: 0.221 G_B: 0.273 cycle_B: 0.258 idt_B: 0.134
# End of epoch 259 / 300 	 Time Taken: 6 sec
# learning rate 0.0000812 -> 0.0000792
# saving the model at the end of epoch 260, iters 3120
# End of epoch 260 / 300 	 Time Taken: 7 sec
# learning rate 0.0000792 -> 0.0000772
# End of epoch 261 / 300 	 Time Taken: 6 sec
# learning rate 0.0000772 -> 0.0000752
# End of epoch 262 / 300 	 Time Taken: 6 sec
# learning rate 0.0000752 -> 0.0000733
# End of epoch 263 / 300 	 Time Taken: 6 sec
# learning rate 0.0000733 -> 0.0000713
# End of epoch 264 / 300 	 Time Taken: 6 sec
# learning rate 0.0000713 -> 0.0000693
# saving the model at the end of epoch 265, iters 3180
# End of epoch 265 / 300 	 Time Taken: 7 sec
# learning rate 0.0000693 -> 0.0000673
# End of epoch 266 / 300 	 Time Taken: 6 sec
# learning rate 0.0000673 -> 0.0000653
# (epoch: 267, iters: 8, time: 2.664, data: 0.000) D_A: 0.217 G_A: 0.347 cycle_A: 0.321 idt_A: 0.088 D_B: 0.211 G_B: 0.272 cycle_B: 0.249 idt_B: 0.106
# End of epoch 267 / 300 	 Time Taken: 8 sec
# learning rate 0.0000653 -> 0.0000634
# End of epoch 268 / 300 	 Time Taken: 6 sec
# learning rate 0.0000634 -> 0.0000614
# End of epoch 269 / 300 	 Time Taken: 6 sec
# learning rate 0.0000614 -> 0.0000594
# saving the model at the end of epoch 270, iters 3240
# End of epoch 270 / 300 	 Time Taken: 7 sec
# learning rate 0.0000594 -> 0.0000574
# End of epoch 271 / 300 	 Time Taken: 6 sec
# learning rate 0.0000574 -> 0.0000554
# End of epoch 272 / 300 	 Time Taken: 6 sec
# learning rate 0.0000554 -> 0.0000535
# End of epoch 273 / 300 	 Time Taken: 6 sec
# learning rate 0.0000535 -> 0.0000515
# End of epoch 274 / 300 	 Time Taken: 6 sec
# learning rate 0.0000515 -> 0.0000495
# (epoch: 275, iters: 12, time: 0.556, data: 0.000) D_A: 0.142 G_A: 0.279 cycle_A: 0.298 idt_A: 0.078 D_B: 0.265 G_B: 0.221 cycle_B: 0.221 idt_B: 0.114
# saving the model at the end of epoch 275, iters 3300
# End of epoch 275 / 300 	 Time Taken: 7 sec
# learning rate 0.0000495 -> 0.0000475
# End of epoch 276 / 300 	 Time Taken: 6 sec
# learning rate 0.0000475 -> 0.0000455
# End of epoch 277 / 300 	 Time Taken: 6 sec
# learning rate 0.0000455 -> 0.0000436
# End of epoch 278 / 300 	 Time Taken: 6 sec
# learning rate 0.0000436 -> 0.0000416
# End of epoch 279 / 300 	 Time Taken: 6 sec
# learning rate 0.0000416 -> 0.0000396
# saving the model at the end of epoch 280, iters 3360
# End of epoch 280 / 300 	 Time Taken: 7 sec
# learning rate 0.0000396 -> 0.0000376
# End of epoch 281 / 300 	 Time Taken: 6 sec
# learning rate 0.0000376 -> 0.0000356
# End of epoch 282 / 300 	 Time Taken: 6 sec
# learning rate 0.0000356 -> 0.0000337
# End of epoch 283 / 300 	 Time Taken: 6 sec
# learning rate 0.0000337 -> 0.0000317
# (epoch: 284, iters: 4, time: 0.557, data: 0.174) D_A: 0.231 G_A: 0.263 cycle_A: 0.273 idt_A: 0.093 D_B: 0.228 G_B: 0.306 cycle_B: 0.250 idt_B: 0.103
# End of epoch 284 / 300 	 Time Taken: 6 sec
# learning rate 0.0000317 -> 0.0000297
# saving the model at the end of epoch 285, iters 3420
# End of epoch 285 / 300 	 Time Taken: 7 sec
# learning rate 0.0000297 -> 0.0000277
# End of epoch 286 / 300 	 Time Taken: 6 sec
# learning rate 0.0000277 -> 0.0000257
# End of epoch 287 / 300 	 Time Taken: 6 sec
# learning rate 0.0000257 -> 0.0000238
# End of epoch 288 / 300 	 Time Taken: 6 sec
# learning rate 0.0000238 -> 0.0000218
# End of epoch 289 / 300 	 Time Taken: 6 sec
# learning rate 0.0000218 -> 0.0000198
# saving the model at the end of epoch 290, iters 3480
# End of epoch 290 / 300 	 Time Taken: 7 sec
# learning rate 0.0000198 -> 0.0000178
# End of epoch 291 / 300 	 Time Taken: 6 sec
# learning rate 0.0000178 -> 0.0000158
# (epoch: 292, iters: 8, time: 0.556, data: 0.002) D_A: 0.204 G_A: 0.270 cycle_A: 0.303 idt_A: 0.079 D_B: 0.194 G_B: 0.249 cycle_B: 0.211 idt_B: 0.123
# End of epoch 292 / 300 	 Time Taken: 6 sec
# learning rate 0.0000158 -> 0.0000139
# End of epoch 293 / 300 	 Time Taken: 6 sec
# learning rate 0.0000139 -> 0.0000119
# End of epoch 294 / 300 	 Time Taken: 6 sec
# learning rate 0.0000119 -> 0.0000099
# saving the model at the end of epoch 295, iters 3540
# End of epoch 295 / 300 	 Time Taken: 7 sec
# learning rate 0.0000099 -> 0.0000079
# End of epoch 296 / 300 	 Time Taken: 6 sec
# learning rate 0.0000079 -> 0.0000059
# End of epoch 297 / 300 	 Time Taken: 6 sec
# learning rate 0.0000059 -> 0.0000040
# End of epoch 298 / 300 	 Time Taken: 6 sec
# learning rate 0.0000040 -> 0.0000020
# End of epoch 299 / 300 	 Time Taken: 6 sec
# learning rate 0.0000020 -> 0.0000000
# (epoch: 300, iters: 12, time: 3.106, data: 0.000) D_A: 0.224 G_A: 0.269 cycle_A: 0.277 idt_A: 0.073 D_B: 0.210 G_B: 0.315 cycle_B: 0.195 idt_B: 0.121
# saving the model at the end of epoch 300, iters 3600
# End of epoch 300 / 300 	 Time Taken: 10 sec

# %% [markdown]
# # Testing
#
# -   `python test.py --dataroot datasets/horse2zebra/testA --name horse2zebra_pretrained --model test --no_dropout`
#
# Change the `--dataroot` and `--name` to be consistent with your trained model's configuration.
#
# > from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix:
# > The option --model test is used for generating results of CycleGAN only for one side. This option will automatically set --dataset_mode single, which only loads the images from one set. On the contrary, using --model cycle_gan requires loading and generating results in both directions, which is sometimes unnecessary. The results will be saved at ./results/. Use --results_dir {directory_path_to_save_result} to specify the results directory.
#
# > For your own experiments, you might want to specify --netG, --norm, --no_dropout to match the generator architecture of the trained model.

# %%
# !cp ./checkpoints/caillet2cruise/latest_net_G_A.pth ./checkpoints/caillet2cruise/latest_net_G.pth

# %%
# !python test.py --dataroot datasets/caillet2cruise/testA --name caillet2cruise --model test --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/caillet2cruise/testA 	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: caillet2cruise                	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: resnet_9blocks
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: instance
#                  num_test: 50
#               num_threads: 4
#                 output_nc: 3
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results/
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [SingleDataset] was created
# initialize network with normal
# model [TestModel] was created
# loading the model from ./checkpoints/caillet2cruise/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 11.378 M
# -----------------------------------------------
# creating web directory ./results/caillet2cruise/test_latest
# processing (0000)-th image... ['datasets/caillet2cruise/testA/001.png']

# %% [markdown]
# # Visualize
#
# 200 Epochs

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('./results/caillet2cruise/test_latest/images/003_fake.png')
plt.imshow(img)

# %%
img = plt.imread('./datasets/caillet2cruise/trainB/002.png')
plt.imshow(img)

# %%
img = plt.imread('./results/caillet2cruise/test_latest/images/003_real.png')
plt.imshow(img)

# %% [markdown]
# # Visualize
#
# 300 Epochs

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('./results/caillet2cruise/test_latest/images/001_fake.png')
plt.imshow(img)

# %%
img = plt.imread('./results/caillet2cruise/test_latest/images/002_fake.png')
plt.imshow(img)

# %%
img = plt.imread('./results/caillet2cruise/test_latest/images/003_fake.png')
plt.imshow(img)

# %%
img = plt.imread('./results/caillet2cruise/test_latest/images/004_fake.png')
plt.imshow(img)

# %%
img = plt.imread('./results/caillet2cruise/test_latest/images/005_fake.png')
plt.imshow(img)

# %%
img = plt.imread('./datasets/caillet2cruise/trainB/002.png')
plt.imshow(img)

# %%
img = plt.imread('./results/caillet2cruise/test_latest/images/001_real.png')
plt.imshow(img)
